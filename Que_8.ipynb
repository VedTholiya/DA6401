# %%
import wandb
import numpy as np
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split
from nnl import NeuralNetwork, Optimizer, Loss, Activation

sweep_config = {
    'method': 'random',
    'name': 'NN_SWEEP_CEL',  
    'metric': {
        'name': 'cel_val_accuracy', 
        'goal': 'maximize'
    },
    'parameters': {
        'n_layers': {
            'values': [2, 3, 4]
        },
        'n_hidden': {
            'values': [64, 128, 256]
        },
        'activation': {
            'values': ['sigmoid', 'relu', 'tanh']
        },
        'learning_rate': {
            'values': [0.01, 0.001, 0.0001]
        },
        'optimizer_method': {
            'values': ['sgd', 'momentum', 'nag', 'rmsprop', 'adam', 'nadam']
        },
        'batch_size': {
            'values': [32, 64, 128]
        },
        'epochs': {
            'values': [5, 10, 15]
        },
        'beta1': {
            'value': 0.9
        },
        'beta2': {
            'value': 0.999
        },
        'epsilon': {
            'value': 1e-8
        },
        'decay': {
            'values': [0.0, 0.5, 0.0005]
        },
        'criterion': {
            'values': ['cross_entropy']  
        }
    }
}

def wandb_sweep():
    run = wandb.init()
    config = wandb.config
    
    run.name = f"cel_l_{config.n_layers}_h_{config.n_hidden}_act_{config.activation}_lr_{config.learning_rate}_bs_{config.batch_size}_opt_{config.optimizer_method}_d_{config.decay}"
    
    activation = Activation(config.activation)
    criterion = Loss(config.criterion)
    optimizer = Optimizer(
        learning_rate=config.learning_rate,
        method=config.optimizer_method,
        config={
            "beta1": config.beta1,
            "beta2": config.beta2,
            "epsilon": config.epsilon,
            "timestep": 0,
            "decay": config.decay,
            "momentum": 0.9,
            "beta": 0.9
        }
    )
    
    nn = NeuralNetwork(
        n_input=784,
        n_output=10,
        n_hidden=config.n_hidden,
        n_layers=config.n_layers,
        activation=activation
    )
    
    histories = train_fashion_mnist(
        nn=nn,
        optimizer=optimizer,
        criterion=criterion,
        epochs=config.epochs,
        batch_size=config.batch_size,
        wandb_logging=True
    )
    
    return histories

# Load fashion MNIST 
def load_fashion_mnist():
    (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
    
    X_train = X_train.reshape(X_train.shape[0], -1).astype('float32') / 255.0
    X_test = X_test.reshape(X_test.shape[0], -1).astype('float32') / 255.0
    
    y_train_onehot = np.zeros((y_train.size, 10))
    y_train_onehot[np.arange(y_train.size), y_train] = 1
    y_test_onehot = np.zeros((y_test.size, 10))
    y_test_onehot[np.arange(y_test.size), y_test] = 1
    
    return X_train, y_train_onehot, X_test, y_test_onehot

def calculate_accuracy(y_true, y_pred):
    predicted_classes = np.argmax(y_pred, axis=1)
    true_classes = np.argmax(y_true, axis=1)
    return np.mean(predicted_classes == true_classes)

def train_fashion_mnist(nn, optimizer, criterion, epochs=10, batch_size=32, wandb_logging=False):
    X_train, y_train, X_test, y_test = load_fashion_mnist()
    
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42
    )
    
    train_loss_hist = []
    train_accuracy_hist = []
    val_loss_hist = []
    val_accuracy_hist = []
    
    n_samples = X_train.shape[0]
    
    for epoch in range(epochs):
        indices = np.random.permutation(n_samples)
        X_train = X_train[indices]
        y_train = y_train[indices]
        
        for i in range(0, n_samples, batch_size):
            X_batch = X_train[i:i+batch_size]
            y_batch = y_train[i:i+batch_size]
            
            y_pred = nn.feedforward(X_batch)
            nn.backpropagation(y_batch, y_pred, criterion.derivative, optimizer)
            optimizer.config["timestep"] += 1
        
        train_preds = nn.feedforward(X_train)
        train_loss = criterion.loss(y_train, train_preds)
        train_accuracy = calculate_accuracy(y_train, train_preds)
        
        val_preds = nn.feedforward(X_val)
        val_loss = criterion.loss(y_val, val_preds)
        val_accuracy = calculate_accuracy(y_val, val_preds)
        
        train_loss_hist.append(train_loss)
        train_accuracy_hist.append(train_accuracy)
        val_loss_hist.append(val_loss)
        val_accuracy_hist.append(val_accuracy)
        
        if wandb_logging:
            wandb.log({
                "epoch": epoch + 1,
                "cel_train_loss": train_loss,
                "cel_train_accuracy": train_accuracy,
                "cel_val_loss": val_loss,
                "cel_val_accuracy": val_accuracy
            })
    
    test_preds = nn.feedforward(X_test)
    test_loss = criterion.loss(y_test, test_preds)
    test_accuracy = calculate_accuracy(y_test, test_preds)
    
    if wandb_logging:
        wandb.log({
            "cel_test_loss": test_loss,
            "cel_test_accuracy": test_accuracy
        })
    
    return train_loss_hist, train_accuracy_hist, val_loss_hist, val_accuracy_hist

if __name__ == "__main__":
    wandb.login(key='f15dba29e56f32e9c31d598bce5bc7a3c76de62e')
    
    sweep_id = wandb.sweep(sweep_config, project="DA6401 - Assignment 1")
    
    wandb.agent(sweep_id, function=wandb_sweep, count=100)
    
    api = wandb.Api()
    sweep = api.sweep(f"ma23c047-indian-institute-of-technology-madras/DA6401 - Assignment 1/{sweep_id}")
    best_run = sweep.best_run()
    
    print("\nBest Configuration:")
    print("-------------------")
    print(f"Best Validation Accuracy: {best_run.summary.get('cel_val_accuracy'):.4f}")
    print(f"Parameters:")
    for key, value in best_run.config.items():
        print(f"{key}: {value}")
# Out:
# Epoch 1/15:
# Train Loss: 0.0471, Train Accuracy: 0.8273
# Test Loss: 0.0503, Test Accuracy: 0.8156
#
# Epoch 2/15:
# Train Loss: 0.0467, Train Accuracy: 0.8224
# Test Loss: 0.0511, Test Accuracy: 0.8041
#
# Epoch 3/15:
# Train Loss: 0.0382, Train Accuracy: 0.8603
# Test Loss: 0.0427, Test Accuracy: 0.8435
#
# Epoch 4/15:
# Train Loss: 0.0369, Train Accuracy: 0.8620
# Test Loss: 0.0420, Test Accuracy: 0.8497
#
# Epoch 5/15:
# Train Loss: 0.0333, Train Accuracy: 0.8792
# Test Loss: 0.0384, Test Accuracy: 0.8628
#
# Epoch 6/15:
# Train Loss: 0.0353, Train Accuracy: 0.8657
# Test Loss: 0.0412, Test Accuracy: 0.8447
#
# Epoch 7/15:
# Train Loss: 0.0309, Train Accuracy: 0.8862
# Test Loss: 0.0373, Test Accuracy: 0.8654
#
# Epoch 8/15:
# Train Loss: 0.0306, Train Accuracy: 0.8854
# Test Loss: 0.0372, Test Accuracy: 0.8645
#
# Epoch 9/15:
# Train Loss: 0.0305, Train Accuracy: 0.8837
# Test Loss: 0.0378, Test Accuracy: 0.8611
#
# Epoch 10/15:
# Train Loss: 0.0280, Train Accuracy: 0.8951
# Test Loss: 0.0353, Test Accuracy: 0.8722
#
# Epoch 11/15:
# Train Loss: 0.0269, Train Accuracy: 0.9005
# Test Loss: 0.0345, Test Accuracy: 0.8752
#
# Epoch 12/15:
# Train Loss: 0.0280, Train Accuracy: 0.8947
# Test Loss: 0.0366, Test Accuracy: 0.8663
#
# Epoch 13/15:
# Train Loss: 0.0265, Train Accuracy: 0.9011
# Test Loss: 0.0354, Test Accuracy: 0.8735
#
# Epoch 14/15:
# Train Loss: 0.0280, Train Accuracy: 0.8885
# Test Loss: 0.0374, Test Accuracy: 0.8583
#
# Epoch 15/15:
# Train Loss: 0.0262, Train Accuracy: 0.9005
# Test Loss: 0.0352, Test Accuracy: 0.8714
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\vedpr\_netrc
# wandb: Currently logged in as: ma23c047 (ma23c047-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Create sweep with ID: b6iz98de
# Sweep URL: https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de
# wandb: Agent Starting Run: b4u72d1a with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 256
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: momentum
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_123620-b4u72d1a</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/b4u72d1a' target="_blank">eager-sweep-1</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/b4u72d1a' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/b4u72d1a</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▆█▇▅▁▂▇▂▃▂</td></tr><tr><td>cel_val_accuracy</td><td>▆██▅▁▃▆▂▃▂</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.6447</td></tr><tr><td>cel_train_accuracy</td><td>0.6552</td></tr><tr><td>cel_val_accuracy</td><td>0.65133</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_256_act_sigmoid_lr_0.01_bs_32_opt_momentum_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/b4u72d1a' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/b4u72d1a</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_123620-b4u72d1a\logs</code>
# wandb: Agent Starting Run: 72ofuamn with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.001
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: momentum
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_123744-72ofuamn</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/72ofuamn' target="_blank">dainty-sweep-2</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/72ofuamn' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/72ofuamn</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▁▅▃█▁▇▇█▇▅▆▆▇▆</td></tr><tr><td>cel_val_accuracy</td><td>▂▂▅▃█▁▇▇▇▆▅▇▆▇▆</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.839</td></tr><tr><td>cel_train_accuracy</td><td>0.85922</td></tr><tr><td>cel_val_accuracy</td><td>0.84783</td></tr><tr><td>epoch</td><td>15</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_128_act_relu_lr_0.001_bs_64_opt_momentum_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/72ofuamn' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/72ofuamn</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_123744-72ofuamn\logs</code>
# wandb: Agent Starting Run: 5pt7hpth with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.0001
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: rmsprop
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_123914-5pt7hpth</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/5pt7hpth' target="_blank">lunar-sweep-3</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/5pt7hpth' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/5pt7hpth</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▄▅▆▆▇▇▇██</td></tr><tr><td>cel_val_accuracy</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8514</td></tr><tr><td>cel_train_accuracy</td><td>0.86776</td></tr><tr><td>cel_val_accuracy</td><td>0.8595</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_64_act_relu_lr_0.0001_bs_128_opt_rmsprop_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/5pt7hpth' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/5pt7hpth</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_123914-5pt7hpth\logs</code>
# wandb: Agent Starting Run: ei4083pi with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.0001
# wandb: 	n_hidden: 256
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: nag
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_123946-ei4083pi</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ei4083pi' target="_blank">crimson-sweep-4</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ei4083pi' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ei4083pi</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▃▄▅▆▆▇▇█▇</td></tr><tr><td>cel_val_accuracy</td><td>▁▃▆▆▆▆▇▇█▇</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8719</td></tr><tr><td>cel_train_accuracy</td><td>0.90093</td></tr><tr><td>cel_val_accuracy</td><td>0.88033</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_256_act_relu_lr_0.0001_bs_64_opt_nag_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ei4083pi' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ei4083pi</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_123946-ei4083pi\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: r7j0846k with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.0001
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: adam
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124141-r7j0846k</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/r7j0846k' target="_blank">copper-sweep-5</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/r7j0846k' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/r7j0846k</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▃▄▅▆▆▇███</td></tr><tr><td>cel_val_accuracy</td><td>▁▄▅▅▆▆████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.874</td></tr><tr><td>cel_train_accuracy</td><td>0.89669</td></tr><tr><td>cel_val_accuracy</td><td>0.88133</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_128_act_tanh_lr_0.0001_bs_32_opt_adam_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/r7j0846k' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/r7j0846k</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124141-r7j0846k\logs</code>
# wandb: Agent Starting Run: 9rs14jjd with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: nag
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124442-9rs14jjd</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9rs14jjd' target="_blank">clean-sweep-6</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9rs14jjd' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9rs14jjd</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▂▁▅▅▅▄▆▅▆▇▇▇█▇█</td></tr><tr><td>cel_val_accuracy</td><td>▂▁▄▄▅▄▆▅▆▆█▇█▅▇</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8362</td></tr><tr><td>cel_train_accuracy</td><td>0.86348</td></tr><tr><td>cel_val_accuracy</td><td>0.84683</td></tr><tr><td>epoch</td><td>15</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_64_act_sigmoid_lr_0.01_bs_32_opt_nag_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9rs14jjd' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9rs14jjd</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124442-9rs14jjd\logs</code>
# wandb: Agent Starting Run: m0iub9kj with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.0005
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: sgd
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124557-m0iub9kj</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/m0iub9kj' target="_blank">rosy-sweep-7</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/m0iub9kj' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/m0iub9kj</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▄▅▇█</td></tr><tr><td>cel_val_accuracy</td><td>▁▃▆██</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8614</td></tr><tr><td>cel_train_accuracy</td><td>0.8795</td></tr><tr><td>cel_val_accuracy</td><td>0.86933</td></tr><tr><td>epoch</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_128_act_sigmoid_lr_0.01_bs_128_opt_sgd_d_0.0005</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/m0iub9kj' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/m0iub9kj</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124557-m0iub9kj\logs</code>
# wandb: Agent Starting Run: 4099cnzg with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.001
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 3
# wandb: 	optimizer_method: sgd
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124613-4099cnzg</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/4099cnzg' target="_blank">olive-sweep-8</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/4099cnzg' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/4099cnzg</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▃▄▄▆▅▆▇▇▇▆▇█▇▇</td></tr><tr><td>cel_val_accuracy</td><td>▁▃▆▅▇▆▇█▇█▆▇█▇▇</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8733</td></tr><tr><td>cel_train_accuracy</td><td>0.90539</td></tr><tr><td>cel_val_accuracy</td><td>0.87933</td></tr><tr><td>epoch</td><td>15</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_3_h_128_act_relu_lr_0.001_bs_64_opt_sgd_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/4099cnzg' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/4099cnzg</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124613-4099cnzg\logs</code>
# wandb: Agent Starting Run: ceyaxg9z with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: rmsprop
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124711-ceyaxg9z</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ceyaxg9z' target="_blank">polar-sweep-9</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ceyaxg9z' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ceyaxg9z</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▇▆▆▁█</td></tr><tr><td>cel_val_accuracy</td><td>█▆▅▁█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.7943</td></tr><tr><td>cel_train_accuracy</td><td>0.80315</td></tr><tr><td>cel_val_accuracy</td><td>0.797</td></tr><tr><td>epoch</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_128_act_sigmoid_lr_0.01_bs_64_opt_rmsprop_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ceyaxg9z' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ceyaxg9z</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124711-ceyaxg9z\logs</code>
# wandb: Agent Starting Run: hme0e0m9 with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.001
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 4
# wandb: 	optimizer_method: nadam
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124758-hme0e0m9</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/hme0e0m9' target="_blank">treasured-sweep-10</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/hme0e0m9' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/hme0e0m9</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>cel_val_accuracy</td><td>▁▅▇▇█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8625</td></tr><tr><td>cel_train_accuracy</td><td>0.88335</td></tr><tr><td>cel_val_accuracy</td><td>0.8705</td></tr><tr><td>epoch</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_4_h_64_act_sigmoid_lr_0.001_bs_64_opt_nadam_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/hme0e0m9' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/hme0e0m9</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124758-hme0e0m9\logs</code>
# wandb: Agent Starting Run: sys47687 with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.0001
# wandb: 	n_hidden: 256
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: nadam
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_124825-sys47687</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/sys47687' target="_blank">apricot-sweep-11</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/sys47687' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/sys47687</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▃▄▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>cel_val_accuracy</td><td>▁▃▄▅▅▆▆▇▆▇▇█▇██</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.867</td></tr><tr><td>cel_train_accuracy</td><td>0.88924</td></tr><tr><td>cel_val_accuracy</td><td>0.88</td></tr><tr><td>epoch</td><td>15</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_256_act_tanh_lr_0.0001_bs_64_opt_nadam_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/sys47687' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/sys47687</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_124825-sys47687\logs</code>
# wandb: Agent Starting Run: qtx7xr1i with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: momentum
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_125103-qtx7xr1i</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qtx7xr1i' target="_blank">swept-sweep-12</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qtx7xr1i' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qtx7xr1i</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁█▁▁▁</td></tr><tr><td>cel_val_accuracy</td><td>▁█▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.1001</td></tr><tr><td>cel_train_accuracy</td><td>0.09985</td></tr><tr><td>cel_val_accuracy</td><td>0.10317</td></tr><tr><td>epoch</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_64_act_relu_lr_0.01_bs_32_opt_momentum_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qtx7xr1i' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qtx7xr1i</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_125103-qtx7xr1i\logs</code>
# wandb: Agent Starting Run: g15a9gqt with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 3
# wandb: 	optimizer_method: momentum
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_125130-g15a9gqt</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/g15a9gqt' target="_blank">crisp-sweep-13</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
# ...
#  View run <strong style="color:#cdcd00">cel_l_4_h_128_act_sigmoid_lr_0.0001_bs_128_opt_sgd_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qb4ts6ih' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/qb4ts6ih</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_144913-qb4ts6ih\logs</code>
# wandb: Agent Starting Run: jszvgq45 with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 256
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: nadam
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_145043-jszvgq45</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/jszvgq45' target="_blank">devout-sweep-97</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/jszvgq45' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/jszvgq45</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▄▇▆█▆▃▅█▆▆█▇▅▇</td></tr><tr><td>cel_val_accuracy</td><td>▁▄▇▆█▆▄▄█▆▆█▇▆█</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.839</td></tr><tr><td>cel_train_accuracy</td><td>0.85841</td></tr><tr><td>cel_val_accuracy</td><td>0.8575</td></tr><tr><td>epoch</td><td>15</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_256_act_sigmoid_lr_0.01_bs_128_opt_nadam_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/jszvgq45' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/jszvgq45</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_145043-jszvgq45\logs</code>
# wandb: Agent Starting Run: ghsiyra8 with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.0001
# wandb: 	n_hidden: 128
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: sgd
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_145229-ghsiyra8</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ghsiyra8' target="_blank">resilient-sweep-98</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ghsiyra8' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ghsiyra8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>cel_val_accuracy</td><td>▁▅▇██</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.7505</td></tr><tr><td>cel_train_accuracy</td><td>0.75856</td></tr><tr><td>cel_val_accuracy</td><td>0.75217</td></tr><tr><td>epoch</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_128_act_sigmoid_lr_0.0001_bs_32_opt_sgd_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ghsiyra8' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/ghsiyra8</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_145229-ghsiyra8\logs</code>
# wandb: Agent Starting Run: 9tt8sl4b with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.001
# wandb: 	n_hidden: 256
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: adam
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_145300-9tt8sl4b</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9tt8sl4b' target="_blank">olive-sweep-99</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9tt8sl4b' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9tt8sl4b</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▁▄▅▆▆▆▇▇██</td></tr><tr><td>cel_val_accuracy</td><td>▁▅▇▇▇▇████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.8809</td></tr><tr><td>cel_train_accuracy</td><td>0.91683</td></tr><tr><td>cel_val_accuracy</td><td>0.89</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_256_act_sigmoid_lr_0.001_bs_32_opt_adam_d_0</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9tt8sl4b' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/9tt8sl4b</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_145300-9tt8sl4b\logs</code>
# wandb: Agent Starting Run: 94g9d0lk with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	criterion: cross_entropy
# wandb: 	decay: 0.5
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	learning_rate: 0.01
# wandb: 	n_hidden: 64
# wandb: 	n_layers: 2
# wandb: 	optimizer_method: rmsprop
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\vedpr\OneDrive\Documents\GitHub\DA6401\wandb\run-20250317_145534-94g9d0lk</code>
# Syncing run <strong><a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/94g9d0lk' target="_blank">fresh-sweep-100</a></strong> to <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View project at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a>
#  View sweep at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/sweeps/b6iz98de</a>
#  View run at <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/94g9d0lk' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/94g9d0lk</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>▁</td></tr><tr><td>cel_train_accuracy</td><td>▄██▃▅█▇▂█▁</td></tr><tr><td>cel_val_accuracy</td><td>▄▇█▃▅█▇▂█▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cel_test_accuracy</td><td>0.7549</td></tr><tr><td>cel_train_accuracy</td><td>0.77365</td></tr><tr><td>cel_val_accuracy</td><td>0.76683</td></tr><tr><td>epoch</td><td>10</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cel_l_2_h_64_act_sigmoid_lr_0.01_bs_128_opt_rmsprop_d_0.5</strong> at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/94g9d0lk' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201/runs/94g9d0lk</a><br> View project at: <a href='https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201' target="_blank">https://wandb.ai/ma23c047-indian-institute-of-technology-madras/DA6401%20-%20Assignment%201</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_145534-94g9d0lk\logs</code>
# wandb: Sorting runs by -summary_metrics.cel_val_accuracy
# Best Configuration:
# -------------------
# Best Validation Accuracy: 0.8900
# Parameters:
# beta1: 0.9
# beta2: 0.999
# decay: 0
# epochs: 10
# epsilon: 1e-08
# n_hidden: 256
# n_layers: 2
# criterion: cross_entropy
# activation: sigmoid
# batch_size: 32
# learning_rate: 0.001
# optimizer_method: adam
